# %%
import pandas as pd 
dataset = pd.read_csv("file:///C:/Users/HP-/Downloads/walmart-sales-dataset-of-45stores.csv")
dataset.head()
# Out:
#    Store        Date  Weekly_Sales  Holiday_Flag  Temperature  Fuel_Price  \
# 0      1    5/2/2010    1643690.90             0        42.31       2.572
# 1      1   12/2/2010    1641957.44             1        38.51       2.548
# 2      1  19-02-2010    1611968.17             0        39.93       2.514
# 3      1  26-02-2010    1409727.59             0        46.63       2.561
# 4      1    5/3/2010    1554806.68             0        46.50       2.625
#
#           CPI  Unemployment
# 0  211.096358         8.106
# 1  211.242170         8.106
# 2  211.289143         8.106
# 3  211.319643         8.106
# 4  211.350143         8.106

# %%
dataset.drop(index=2)
# Out:
#       Store        Date  Weekly_Sales  Holiday_Flag  Temperature  Fuel_Price  \
# 0         1    5/2/2010    1643690.90             0        42.31       2.572
# 1         1   12/2/2010    1641957.44             1        38.51       2.548
# 3         1  26-02-2010    1409727.59             0        46.63       2.561
# 4         1    5/3/2010    1554806.68             0        46.50       2.625
# 5         1   12/3/2010    1439541.59             0        57.79       2.667
# ...     ...         ...           ...           ...          ...         ...
# 6430     45  28-09-2012     713173.95             0        64.88       3.997
# 6431     45   5/10/2012     733455.07             0        64.89       3.985
# 6432     45  12/10/2012     734464.36             0        54.47       4.000
# 6433     45  19-10-2012     718125.53             0        56.47       3.969
# 6434     45  26-10-2012     760281.43             0        58.85       3.882
#
#              CPI  Unemployment
# ...

# %%
dataset.drop([0,1,3])
# Out:
#       Store        Date  Weekly_Sales  Holiday_Flag  Temperature  Fuel_Price  \
# 2         1  19-02-2010    1611968.17             0        39.93       2.514
# 4         1    5/3/2010    1554806.68             0        46.50       2.625
# 5         1   12/3/2010    1439541.59             0        57.79       2.667
# 6         1  19-03-2010    1472515.79             0        54.58       2.720
# 7         1  26-03-2010    1404429.92             0        51.45       2.732
# ...     ...         ...           ...           ...          ...         ...
# 6430     45  28-09-2012     713173.95             0        64.88       3.997
# 6431     45   5/10/2012     733455.07             0        64.89       3.985
# 6432     45  12/10/2012     734464.36             0        54.47       4.000
# 6433     45  19-10-2012     718125.53             0        56.47       3.969
# 6434     45  26-10-2012     760281.43             0        58.85       3.882
#
#              CPI  Unemployment
# ...

# %%
dataset.drop(columns='Store')
# Out:
#             Date  Weekly_Sales  Holiday_Flag  Temperature  Fuel_Price  \
# 0       5/2/2010    1643690.90             0        42.31       2.572
# 1      12/2/2010    1641957.44             1        38.51       2.548
# 2     19-02-2010    1611968.17             0        39.93       2.514
# 3     26-02-2010    1409727.59             0        46.63       2.561
# 4       5/3/2010    1554806.68             0        46.50       2.625
# ...          ...           ...           ...          ...         ...
# 6430  28-09-2012     713173.95             0        64.88       3.997
# 6431   5/10/2012     733455.07             0        64.89       3.985
# 6432  12/10/2012     734464.36             0        54.47       4.000
# 6433  19-10-2012     718125.53             0        56.47       3.969
# 6434  26-10-2012     760281.43             0        58.85       3.882
#
#              CPI  Unemployment
# 0     211.096358         8.106
# 1     211.242170         8.106
# ...

# %%
import pandas as pd
import numpy as np

# %%
def load_df(): 
  return pd.DataFrame({
    'Temperature': [42.31,38.51,39.93,46.63],
    'Holiday_Flag': [0,1,0,0],
      'Weekly_Sales' : [1643690.90,1641957.44 ,1611968.17,1409727.59]
  })

# %%
df = load_df()
df
# Out:
#    Temperature  Holiday_Flag  Weekly_Sales
# 0        42.31             0    1643690.90
# 1        38.51             1    1641957.44
# 2        39.93             0    1611968.17
# 3        46.63             0    1409727.59

# %%
df.dtypes
# Out:
# Temperature     float64
# Holiday_Flag      int64
# Weekly_Sales    float64
# dtype: object

# %%
df.Holiday_Flag.dtypes
# Out:
# dtype('int64')

# %%
df['Temperature'] = df['Temperature'].astype('int')
df
# Out:
#    Temperature  Holiday_Flag  Weekly_Sales
# 0           42             0    1643690.90
# 1           38             1    1641957.44
# 2           39             0    1611968.17
# 3           46             0    1409727.59

# %%
import pandas as pd

# %%
dataset=pd.read.csv('file:///C:/Users/HP-/Downloads/walmart-sales-dataset-of-45stores.csv')

# %%
dataset.isnull().iloc[0:25,:]
# Out:
#     Store   Date  Weekly_Sales  Holiday_Flag  Temperature  Fuel_Price    CPI  \
# 0   False  False         False         False        False       False  False
# 1   False  False         False         False        False       False  False
# 2   False  False         False         False        False       False  False
# 3   False  False         False         False        False       False  False
# 4   False  False         False         False        False       False  False
# 5   False  False         False         False        False       False  False
# 6   False  False         False         False        False       False  False
# 7   False  False         False         False        False       False  False
# 8   False  False         False         False        False       False  False
# 9   False  False         False         False        False       False  False
# 10  False  False         False         False        False       False  False
# ...

# %%
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt 
import seaborn as sns

# %%
appointment_df=pd.read_csv('file:///C:/Users/HP-/Downloads/walmart-sales-dataset-of-45stores.csv')
appointment_df.head()
# Out:
#    Store        Date  Weekly_Sales  Holiday_Flag  Temperature  Fuel_Price  \
# 0      1    5/2/2010    1643690.90             0        42.31       2.572
# 1      1   12/2/2010    1641957.44             1        38.51       2.548
# 2      1  19-02-2010    1611968.17             0        39.93       2.514
# 3      1  26-02-2010    1409727.59             0        46.63       2.561
# 4      1    5/3/2010    1554806.68             0        46.50       2.625
#
#           CPI  Unemployment
# 0  211.096358         8.106
# 1  211.242170         8.106
# 2  211.289143         8.106
# 3  211.319643         8.106
# 4  211.350143         8.106

# %%
appointment_df.describe()
# Out:
#              Store  Weekly_Sales  Holiday_Flag  Temperature   Fuel_Price  \
# count  6435.000000  6.435000e+03   6435.000000  6435.000000  6435.000000
# mean     23.000000  1.046965e+06      0.069930    60.663782     3.358607
# std      12.988182  5.643666e+05      0.255049    18.444933     0.459020
# min       1.000000  2.099862e+05      0.000000    -2.060000     2.472000
# 25%      12.000000  5.533501e+05      0.000000    47.460000     2.933000
# 50%      23.000000  9.607460e+05      0.000000    62.670000     3.445000
# 75%      34.000000  1.420159e+06      0.000000    74.940000     3.735000
# max      45.000000  3.818686e+06      1.000000   100.140000     4.468000
#
#                CPI  Unemployment
# count  6435.000000   6435.000000
# mean    171.578394      7.999151
# std      39.356712      1.875885
# min     126.064000      3.879000
# 25%     131.735000      6.891000
# 50%     182.616521      7.874000
# 75%     212.743293      8.622000
# max     227.232807     14.313000

# %%
appointment_df.shape
# Out:
# (6435, 8)

# %%
appointment_df.info
# Out:
# <bound method DataFrame.info of       Store        Date  Weekly_Sales  Holiday_Flag  Temperature  Fuel_Price  \
# 0         1    5/2/2010    1643690.90             0        42.31       2.572
# 1         1   12/2/2010    1641957.44             1        38.51       2.548
# 2         1  19-02-2010    1611968.17             0        39.93       2.514
# 3         1  26-02-2010    1409727.59             0        46.63       2.561
# 4         1    5/3/2010    1554806.68             0        46.50       2.625
# ...     ...         ...           ...           ...          ...         ...
# 6430     45  28-09-2012     713173.95             0        64.88       3.997
# 6431     45   5/10/2012     733455.07             0        64.89       3.985
# 6432     45  12/10/2012     734464.36             0        54.47       4.000
# 6433     45  19-10-2012     718125.53             0        56.47       3.969
# 6434     45  26-10-2012     760281.43             0        58.85       3.882
#
# ...

# %%
sum(appointment_df.duplicated())
# Out:
# 0

# %%
appointment_df.hist(figsize=(15,8));
